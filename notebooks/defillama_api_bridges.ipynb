# %%
from defillama2 import DefiLlama
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 15)
pd.set_option('display.max_rows', 50)
pd.options.display.float_format = '{:,.4f}'.format

# %%
obj = DefiLlama()

# %% [markdown]
# ## Get volume summary of all bridges

# %%
df = obj.get_bridges_volumes()
df.head()
# Out:
#    id         displayName   volumePrevDay  volumePrev2Day  lastHourlyVolume  \
# 0   5          Multichain 34,630,033.7486 28,983,816.5663       53,549.4158
# 1   2     Arbitrum Bridge  8,435,105.2498 52,319,773.6589      401,220.8498
# 2   1  Polygon PoS Bridge  7,399,139.3694  9,248,095.6382       39,727.3198
# 3   3    Avalanche Bridge  5,735,424.6679  5,429,579.7382      127,971.2431
# 4   4    Optimism Gateway  1,747,054.2529  5,876,501.7951       17,474.3271
#
#    currentDayVolume  lastDailyVolume  dayBeforeLastVolume     weeklyVolume  \
# 0    1,729,717.8213  34,630,033.7486      28,983,816.5663 212,361,113.3672
# 1      766,588.7568   8,435,105.2498      52,319,773.6589  98,176,129.2728
# 2    5,975,641.0363   7,399,139.3694       9,248,095.6382  80,850,539.1209
# 3      363,885.5100   5,735,424.6679       5,429,579.7382  32,354,785.5946
# 4       36,175.5377   1,747,054.2529       5,876,501.7951  34,328,346.8339
#
#      monthlyVolume  chainsCnt
# 0 806,857,792.9381          9
# 1 644,212,539.3241          2
# 2 469,622,562.5225          2
# 3 147,632,426.2688          2
# 4 232,196,201.7527          2

# %%
dd = obj.get_bridge_volume(bridge_id=1)
dd.keys()
# Out:
# dict_keys(['summary', 'summary_by_chain', 'deposits_withdraws_by_chain'])

# %%
dd['summary']
# Out:
#           displayName  lastHourlyVolume  currentDayVolume  lastDailyVolume  \
# 0  Polygon PoS Bridge                 0    5,975,641.0363   7,399,139.3694
#
#    dayBeforeLastVolume     weeklyVolume    monthlyVolume  lastHourlyTxs  \
# 0       9,248,095.6382 102,315,205.2258 469,622,562.5225         0.0000
#
#    currentDayTxs  prevDayTxs  dayBeforeLastTxs  weeklyTxs  monthlyTxs
# 0       180.0000  1,132.0000        1,101.0000 9,354.0000 45,674.0000

# %%
dd['summary_by_chain']
# Out:
#       chain  lastHourlyVolume  currentDayVolume  lastDailyVolume  \
# 0  Ethereum                 0    2,987,820.5181   3,699,569.6847
# 1   Polygon                 0    2,987,820.5181   3,699,569.6847
#
#    dayBeforeLastVolume    weeklyVolume    monthlyVolume
# 0       4,624,047.8191 51,157,602.6129 234,811,281.2613
# 1       4,624,047.8191 51,157,602.6129 234,811,281.2613

# %%
dd['deposits_withdraws_by_chain']
# Out:
#       chain       txType  lastHourlyTxs  currentDayTxs  prevDayTxs  \
# 0  Ethereum     deposits              0            126         745
# 1  Ethereum  withdrawals              0             54         387
# 2   Polygon     deposits              0             54         387
# 3   Polygon  withdrawals              0            126         745
#
#    dayBeforeLastTxs  weeklyTxs  monthlyTxs
# 0               726       6573       32998
# 1               375       2781       12676
# 2               375       2781       12676
# 3               726       6573       32998

# %% [markdown]
# ## Get daily volumes from a particular bridge

# %%
# on all chains
df = obj.get_daily_volume_this_bridge(bridge_id=5, chain='all')
df.head()
# Out:
#                                depositUSD     withdrawUSD  depositTxs  \
# date
# 2022-09-01 00:00:00+00:00 26,913,837.4464 29,735,340.1374        2806
# 2022-09-02 00:00:00+00:00 39,286,336.5884 43,214,576.7587        2785
# 2022-09-03 00:00:00+00:00 37,001,903.8771 36,758,187.6804        2400
# 2022-09-04 00:00:00+00:00 28,691,939.8860 45,164,333.4297        2524
# 2022-09-05 00:00:00+00:00 58,983,401.1159 58,935,825.8395        3171
#
#                            withdrawTxs
# date
# 2022-09-01 00:00:00+00:00         2590
# 2022-09-02 00:00:00+00:00         2709
# 2022-09-03 00:00:00+00:00         2381
# 2022-09-04 00:00:00+00:00         2576
# 2022-09-05 00:00:00+00:00         3096

# %%
# on ethereum
df = obj.get_daily_volume_this_bridge(bridge_id=5, chain='ethereum')
df.head()
# Out:
#                                depositUSD     withdrawUSD  depositTxs  \
# date
# 2022-09-01 00:00:00+00:00  7,399,628.7693 10,805,446.9631         547
# 2022-09-02 00:00:00+00:00 12,421,985.6609 11,612,565.9071         588
# 2022-09-03 00:00:00+00:00  5,604,725.6731  6,814,770.2775         546
# 2022-09-04 00:00:00+00:00  7,224,908.8936 16,464,749.8037         544
# 2022-09-05 00:00:00+00:00  8,225,943.3939 15,686,139.3990         607
#
#                            withdrawTxs
# date
# 2022-09-01 00:00:00+00:00          465
# 2022-09-02 00:00:00+00:00          476
# 2022-09-03 00:00:00+00:00          338
# 2022-09-04 00:00:00+00:00          419
# 2022-09-05 00:00:00+00:00          635

# %% [markdown]
# ## Get 24hr token and volume breakdown for a bridge.

# %%
# get token and volume breakdown for bridge 5 on Ethereum
# 24hr since 2022-12-22 UTC 00:00 
df = obj.get_24h_token_volume_this_bridge(
    bridge_id=5, chain='ethereum', date='2022-12-22')
df.head()
# Out:
#   symbol TokensDeposited_usdValue TokensWithdrawn_usdValue  \
# 0   USDT           3,931,620.6695           9,795,198.7199
# 1   USDC             874,672.8780           1,359,680.7559
# 2   WETH             360,474.7623             498,015.4675
# 3   WBTC             154,985.9763              46,653.7167
# 4    ICE              98,471.0538             117,030.6303
#
#    AddressDeposited_usdValue  AddressDeposited_txs  AddressWithdrawn_usdValue  \
# 0             3,503,489.9900                1.0000             8,795,760.1880
# 1               326,755.2288                3.0000               475,464.1204
# 2               288,086.2260                3.0000               310,774.1161
# 3               127,492.8492                1.0000               299,225.5676
# 4               104,162.3858                1.0000               242,908.9689
#
#    AddressWithdrawn_txs
# 0                6.0000
# 1                3.0000
# 2                4.0000
# 3                2.0000
# 4                3.0000

# %%
# get token and volume breakdown for bridge 1 (Polygon PoS) on Polygon
# 24hr since 2022-12-25 UTC 00:00 
df = obj.get_24h_token_volume_this_bridge(
    bridge_id=1, chain='polygon', date='2022-12-25')
df.head()
# Out:
#   symbol TokensDeposited_usdValue TokensWithdrawn_usdValue  \
# 0   USDC           5,246,330.1939             105,580.6504
# 1   WETH           1,947,580.4076             200,657.2063
# 2   USDT              72,470.1628             164,246.7936
# 3   WBTC              34,397.4106             114,208.4068
# 4    MNW              22,144.3191              73,670.5440
#
#    AddressDeposited_usdValue  AddressDeposited_txs  AddressWithdrawn_usdValue  \
# 0             5,004,874.3054                1.0000               153,807.8307
# 1             1,782,946.1299                1.0000                97,321.5912
# 2                90,641.6864                2.0000                84,774.6858
# 3                90,626.2929                4.0000                77,962.3649
# 4                69,323.9470                1.0000                74,285.3601
#
#    AddressWithdrawn_txs
# 0                1.0000
# 1                1.0000
# 2                1.0000
# 3                1.0000
# 4                1.0000

# %% [markdown]
# ## Get all tx (upto 6000 of them) for a bridge within a date range

# %%
fromToAddrs_chains = {
    '0x69b4B4390Bd1f0aE84E090Fe8af7AbAd2d95Cc8E':'ethereum',
}

# %%
df = obj.get_tx_this_bridge(
    bridge_id=1, sourcechain='polygon', 
    start='2022-11-01', end='2022-11-02', 
    fromToAddrs_chains=fromToAddrs_chains, limit=200)
df.head()
# Out:
#                                              tx_hash  \
# 0  0x7a7e54dce4a9f2447742c25b9090f504909e63769318...
# 1  0xa75697c79ff728d9f912b5e95987bfe4b4b99252289b...
#
#                          ts  tx_block  \
# 0  2022-11-01T21:03:35.000Z  15877738
# 1  2022-11-01T20:03:35.000Z  15877442
#
#                                       tx_from  \
# 0  0x8484Ef722627bf18ca5Ae6BcF031c23E6e922B30
# 1  0x8484Ef722627bf18ca5Ae6BcF031c23E6e922B30
#
#                                         tx_to  \
# 0  0x69b4B4390Bd1f0aE84E090Fe8af7AbAd2d95Cc8E
# 1  0x69b4B4390Bd1f0aE84E090Fe8af7AbAd2d95Cc8E
#
#                                         token               amount     chain  \
# 0  0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2  1890000000000000000  ethereum
# 1  0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2    10000000000000000  ethereum
#
#   bridge_name usd_value sourceChain
# 0     polygon      None     polygon
# 1     polygon      None     polygon
