# %%
from defillama2 import DefiLlama
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 15)
pd.set_option('display.max_rows', 50)
pd.options.display.float_format = '{:,.4f}'.format

# %%
obj = DefiLlama()

# %% [markdown]
# ## Get Fees paid to Protocols by users

# %%
dd = obj.get_fees(data_type='dailyFees')
dd.keys()
# Out:
# dict_keys(['fees_overall', 'fees_by_dex', 'fees_by_dex_by_chain_24h', 'daily_fees', 'daily_fees_by_dex'])

# %%
dd['fees_overall']
# Out:
#         total24h         total7d  change_1d  change_7d  change_1m  \
# 0 7,083,687.2373 49,204,636.3574     8.3900    -8.7500    -5.3300
#
#    change_7dover7d
# 0         -19.6000

# %%
dd['fees_by_dex'].head()
# Out:
#           name category   change_1d  change_7d   change_1m  change_7dover7d  \
# 0         0vix  Lending     -0.1200     7.9900     -4.6700          -0.8200
# 1         AAVE  Lending      1.8800    -7.9700    -11.7600           4.5900
# 2  Abracadabra      CDP    609.6500   745.9200 31,538.2000          77.7100
# 3        Angle      CDP 16,956.0100 6,227.7700    -30.3900         -68.5600
# 4  ApeSwap AMM    Dexes     11.8900   -11.4400    -23.5800         -49.2700
#
#       total24h        total7d    totalAllTime  \
# 0     496.0155     3,344.6631     55,977.5924
# 1 165,943.2364 1,196,686.8005          0.0000
# 2  50,549.4505    75,486.0392             NaN
# 3     534.2213    10,241.1731  8,662,273.4075
# 4   1,947.3518    12,228.0427 35,558,387.2899
#
#                                               chains  dailyUserFees  \
# 0                                          [Polygon]            NaN
# 1  [Ethereum, Avalanche, Polygon, Arbitrum, Optim...            NaN
# 2       [Ethereum, Fantom, Avalanche, BSC, Arbitrum]            NaN
# 3            [Ethereum, Optimism, Arbitrum, Polygon]            NaN
# 4                    [BSC, Ethereum, Polygon, Telos]            NaN
#
#    dailyHoldersRevenue dailyCreatorRevenue  dailySupplySideRevenue  \
# 0                  NaN                None                     NaN
# 1                  NaN                None                     NaN
# 2                  NaN                None                     NaN
# 3                  NaN                None                     NaN
# 4                  NaN                None                     NaN
#
#    dailyProtocolRevenue
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
dd['fees_by_dex_by_chain_24h'].head()
# Out:
#   protocol     chain     total24h
# 0     0vix   polygon     496.0155
# 1       v1  ethereum     153.3746
# 2       v2   polygon   4,115.4030
# 3       v2  ethereum 141,910.3247
# 4       v2      avax   1,145.8928

# %%
dd['daily_fees'].head()
# Out:
#                  volume
# date
# 2019-10-11 403,559.2733
# 2019-10-12 331,752.9437
# 2019-10-13 260,963.1440
# 2019-10-14 229,162.7183
# 2019-10-15 308,044.9073

# %%
dd['daily_fees_by_dex'].tail()
# Out:
#                 bitcoin    compound       doge       ethereum  litecoin  \
# date
# 2022-12-23 292,689.3427 46,102.0387 1,757.4634 2,275,021.0053  969.3984
# 2022-12-24 296,554.3263 45,843.3030 1,916.0710 2,124,989.0083  949.7783
# 2022-12-25 292,152.4550 44,657.7190 1,682.1656 1,733,610.6849  894.8683
# 2022-12-26 228,040.7892 49,692.5425 1,374.4331 1,697,415.8380  872.7663
# 2022-12-27 306,349.7505 47,061.7015 1,483.0706 1,847,780.2849  935.0810
#
#                 opensea   synthetix  ...  lifinity  llamalend   avalanche  \
# date                                 ...
# 2022-12-23 695,607.2232 30,028.1435  ...    0.0000   376.5641 10,436.6650
# 2022-12-24 494,707.4764 21,956.5439  ...  953.6347   346.8226  8,481.8430
# 2022-12-25 428,678.0053 17,395.5862  ...    0.0000   346.9121  7,225.7105
# 2022-12-26 546,816.4810 20,602.6015  ...  265.0659   300.1418  8,603.5158
# 2022-12-27 734,523.2026 45,790.1264  ...    0.0000   301.7120  9,517.9586
#
#             perp88       dodo  kperp-exchange  mummy-finance
# date
# 2022-12-23 12.1253 4,025.0626          2.8653     2,040.1772
# 2022-12-24  3.5625 1,920.2236          3.3030     2,849.5956
# 2022-12-25  8.9125 3,839.5065          6.9320       736.1510
# 2022-12-26 14.2626 4,533.7075          2.5395       992.5947
# 2022-12-27  9.0318 4,284.3813          2.1640     2,287.0415
#
# [5 rows x 84 columns]

# %% [markdown]
# ## Get Protocols Revenue (fees accrued by protocol)

# %%
dd = obj.get_fees(data_type='dailyRevenue')
dd.keys()
# Out:
# dict_keys(['revenue_overall', 'revenue_by_dex', 'revenue_by_dex_by_chain_24h', 'daily_revenue', 'daily_revenue_by_dex'])

# %%
dd['revenue_overall']
# Out:
#         total24h         total7d  change_1d  change_7d  change_1m  \
# 0 2,850,466.0766 20,831,873.8519     9.3200   -11.6400    15.7900
#
#    change_7dover7d
# 0         -16.7200

# %%
dd['revenue_by_dex'].head()
# Out:
#           name category   change_1d  change_7d   change_1m  change_7dover7d  \
# 0         0vix  Lending     -0.1200     7.9900     -4.6700          -0.8200
# 1         AAVE  Lending      3.9000    -7.3400     -9.4100          19.6000
# 2  Abracadabra      CDP    609.6500   745.9200 31,538.2000          77.7100
# 3        Angle      CDP 10,256.4900 3,742.2500    -57.7300         -77.9100
# 4  ApeSwap AMM    Dexes     16.9600   -21.2900    -26.7000         -51.6100
#
#      total24h      total7d    totalAllTime  \
# 0    148.8047   1,003.3989     14,054.9275
# 1 22,203.6854 162,194.9529          0.0000
# 2 25,274.7253  37,743.0196             NaN
# 3    324.3817   4,863.4649  6,184,005.6996
# 4    626.3978   4,000.2887 11,539,828.3516
#
#                                               chains  dailyUserFees  \
# 0                                          [Polygon]            NaN
# 1  [Ethereum, Avalanche, Polygon, Arbitrum, Optim...            NaN
# 2       [Ethereum, Fantom, Avalanche, BSC, Arbitrum]            NaN
# 3            [Ethereum, Optimism, Arbitrum, Polygon]            NaN
# 4                    [BSC, Ethereum, Polygon, Telos]            NaN
#
#    dailyHoldersRevenue dailyCreatorRevenue  dailySupplySideRevenue  \
# 0                  NaN                None                     NaN
# 1                  NaN                None                     NaN
# 2                  NaN                None                     NaN
# 3                  NaN                None                     NaN
# 4                  NaN                None                     NaN
#
#    dailyProtocolRevenue
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
print(dd['revenue_by_dex_by_chain_24h'].head(), end='\n\n')
print(dd['revenue_by_dex_by_chain_24h']['chain'].unique())
# Out:
#   protocol     chain    total24h
# 0     0vix   polygon    148.8047
# 1       v1  ethereum      0.0000
# 2       v2   polygon    469.2744
# 3       v2  ethereum 19,034.0560
# 4       v2      avax    118.3874
#
# ['polygon' 'ethereum' 'avax' 'arbitrum' 'optimism' 'fantom' 'harmony'
#  'bsc' 'bitcoin' 'xdai' 'aurora' 'doge' 'telos' 'iotex' 'fuse' 'kcc'
#  'elastos' 'boba' 'moonbeam' 'moonriver' 'neo' 'kava' 'cronos' 'solana'
#  'litecoin' 'cosmos' 'celo' 'tron']

# %%
dd['daily_revenue'].head()
# Out:
#                volume
# date
# 2019-10-11 1,184.0787
# 2019-10-12 1,090.5691
# 2019-10-13 2,415.1142
# 2019-10-14 2,806.7858
# 2019-10-15 2,732.9772

# %%
dd['daily_revenue_by_dex'].tail()
# Out:
#             bitcoin   compound  doge       ethereum  litecoin      opensea  \
# date
# 2022-12-23        0 5,010.7628     0 1,842,702.8357         0 274,516.6818
# 2022-12-24        0 4,899.3818     0 1,737,718.6157         0 183,546.5759
# 2022-12-25        0 4,842.4823     0 1,457,560.3277         0 155,438.6160
# 2022-12-26        0 5,347.7130     0 1,374,105.8810         0 217,989.6773
# 2022-12-27        0 5,078.0533     0 1,483,421.0126         0 280,898.7417
#
#              synthetix  ...  raydium    tarot  lifinity   avalanche     dodo  \
# date                    ...
# 2022-12-23 30,028.1435  ... 742.9576 146.8307    0.0000 10,436.6650 805.0125
# 2022-12-24 21,956.5439  ... 693.4520 117.6000  143.0452  8,481.8430 384.0447
# 2022-12-25 17,395.5862  ... 755.4360 121.7201    0.0000  7,225.7105 767.9013
# 2022-12-26 20,602.6015  ... 770.6823 111.9244   39.7599  8,603.5158 906.7415
# 2022-12-27 45,790.1264  ... 713.2542 103.7966    0.0000  9,517.9586 856.8763
#
#             kperp-exchange  mummy-finance
# date
# 2022-12-23          0.8596       102.0089
# 2022-12-24          0.9909       142.4798
# 2022-12-25          2.0796        36.8075
# 2022-12-26          0.7619        49.6297
# 2022-12-27          0.6492       114.3521
#
# [5 rows x 71 columns]

# %% [markdown]
# ## Get protocols fees on a specific chain

# %%
dd = obj.get_fees_this_chain(chain='ethereum', data_type='dailyFees')
dd.keys()
# Out:
# dict_keys(['fees_overall', 'fees_by_dex', 'fees_by_dex_by_chain_24h', 'daily_fees', 'daily_fees_by_dex'])

# %%
dd['fees_overall']
# Out:
#         total24h         total7d  change_1d  change_7d  change_1m  \
# 0 4,756,658.2147 32,616,092.8367     6.7300    -3.3400     2.7200
#
#    change_7dover7d
# 0         -17.2100

# %%
dd['fees_by_dex'].head()
# Out:
#           name category  change_1d   change_7d   change_1m  change_7dover7d  \
# 0         AAVE  Lending     2.0200     -8.3600     -8.6300           7.6500
# 1  Abracadabra      CDP   614.0100    765.3900 45,783.7600          82.0700
# 2        Angle      CDP        NaN 18,130.1400    -31.1400         -68.5200
# 3  ApeSwap AMM    Dexes 1,291.6000    -80.5000    -81.6800         -53.3200
# 4     Balancer    Dexes    10.5400    -53.9100    -57.4300         -45.6200
#
#       total24h        total7d     totalAllTime      chains  dailyUserFees  \
# 0 142,063.6992 1,025,667.2912           0.0000  [Ethereum]            NaN
# 1  50,477.1197    75,049.0286              NaN  [Ethereum]            NaN
# 2     527.1503    10,194.1236   8,660,886.5198  [Ethereum]            NaN
# 3       0.2811         6.5922       1,290.1466  [Ethereum]            NaN
# 4  11,611.7663    93,869.0197 150,281,764.1059  [Ethereum]            NaN
#
#    dailyHoldersRevenue dailyCreatorRevenue  dailySupplySideRevenue  \
# 0                  NaN                None                     NaN
# 1                  NaN                None                     NaN
# 2                  NaN                None                     NaN
# 3                  NaN                None                     NaN
# 4                  NaN                None                     NaN
#
#    dailyProtocolRevenue
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
dd['fees_by_dex_by_chain_24h'].head()
# Out:
#       protocol     chain     total24h
# 0           v1  ethereum     153.3746
# 1           v2  ethereum 141,910.3247
# 2  abracadabra  ethereum  50,477.1197
# 3        angle  ethereum     527.1503
# 4      apeswap  ethereum       0.2811

# %%
dd['daily_fees'].head()
# Out:
#                  volume
# date
# 2019-10-11 113,193.5088
# 2019-10-12 100,673.5788
# 2019-10-13  91,704.0811
# 2019-10-14  91,997.9260
# 2019-10-15 106,109.1092

# %%
dd['daily_fees_by_dex'].head()
# Out:
#               compound    ethereum    opensea  synthetix    uniswap  makerdao  \
# date
# 2019-10-11 14,413.0431 95,564.4491   427.3362     0.0000 2,788.6805       NaN
# 2019-10-12 14,183.3698 85,008.8943   372.9672     0.0000 1,108.3476       NaN
# 2019-10-13 14,280.3340 70,596.0301 5,551.1769     0.0000 1,276.5401       NaN
# 2019-10-14 14,191.0842 68,302.0090 7,146.3175     0.0000 2,358.5152       NaN
# 2019-10-15 14,391.1652 82,944.9437 6,778.6639     0.0000 1,994.3364       NaN
#
#             curve  ...  frax-swap  premia  stargate  ghostmarket  pancakeswap  \
# date               ...
# 2019-10-11    NaN  ...        NaN     NaN       NaN          NaN          NaN
# 2019-10-12    NaN  ...        NaN     NaN       NaN          NaN          NaN
# 2019-10-13    NaN  ...        NaN     NaN       NaN          NaN          NaN
# 2019-10-14    NaN  ...        NaN     NaN       NaN          NaN          NaN
# 2019-10-15    NaN  ...        NaN     NaN       NaN          NaN          NaN
#
#             llamalend  dodo
# date
# 2019-10-11        NaN   NaN
# 2019-10-12        NaN   NaN
# 2019-10-13        NaN   NaN
# 2019-10-14        NaN   NaN
# 2019-10-15        NaN   NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Get protocols revenue on a specific chain

# %%
dd = obj.get_fees_this_chain(chain='ethereum', data_type='dailyRevenue')
dd.keys()
# Out:
# dict_keys(['revenue_overall', 'revenue_by_dex', 'revenue_by_dex_by_chain_24h', 'daily_revenue', 'daily_revenue_by_dex'])

# %%
dd['revenue_overall']
# Out:
#         total24h         total7d  change_1d  change_7d  change_1m  \
# 0 2,063,754.9886 15,357,726.6217    10.1400    -9.2800    16.0800
#
#    change_7dover7d
# 0         -14.4300

# %%
dd['revenue_by_dex'].head()
# Out:
#           name category  change_1d   change_7d   change_1m  change_7dover7d  \
# 0         AAVE  Lending     3.4700     -6.8200     -7.2100          28.5700
# 1  Abracadabra      CDP   614.0100    765.3900 45,783.7600          82.0700
# 2        Angle      CDP        NaN 10,873.3700    -58.5500         -77.9300
# 3  ApeSwap AMM    Dexes 1,291.6000    -80.5000    -81.6800         -53.3200
# 4     Balancer    Dexes    -0.7000    -68.5300    -61.3300         -50.4800
#
#      total24h      total7d    totalAllTime      chains  dailyUserFees  \
# 0 19,034.0560 140,840.9048          0.0000  [Ethereum]            NaN
# 1 25,238.5598  37,524.5143             NaN  [Ethereum]            NaN
# 2    317.3106   4,816.4155  6,182,618.8119  [Ethereum]            NaN
# 3      0.0703       1.6480        322.5367  [Ethereum]            NaN
# 4  3,428.9103  34,380.0169 10,010,088.2147  [Ethereum]            NaN
#
#    dailyHoldersRevenue dailyCreatorRevenue  dailySupplySideRevenue  \
# 0                  NaN                None                     NaN
# 1                  NaN                None                     NaN
# 2                  NaN                None                     NaN
# 3                  NaN                None                     NaN
# 4                  NaN                None                     NaN
#
#    dailyProtocolRevenue
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
dd['revenue_by_dex_by_chain_24h'].head()
# Out:
#       protocol     chain    total24h
# 0           v1  ethereum      0.0000
# 1           v2  ethereum 19,034.0560
# 2  abracadabra  ethereum 25,238.5598
# 3        angle  ethereum    317.3106
# 4      apeswap  ethereum      0.0703

# %%
dd['daily_revenue'].head()
# Out:
#                volume
# date
# 2019-10-11 1,184.0787
# 2019-10-12 1,090.5691
# 2019-10-13 2,415.1142
# 2019-10-14 2,806.7858
# 2019-10-15 2,732.9772

# %%
dd['daily_revenue_by_dex'].head()
# Out:
#             compound  ethereum    opensea  synthetix  uniswap  makerdao  \
# date
# 2019-10-11  998.2746    0.0000   185.8041     0.0000        0       NaN
# 2019-10-12  980.0384    0.0000   110.5307     0.0000        0       NaN
# 2019-10-13  984.6373    0.0000 1,430.4769     0.0000        0       NaN
# 2019-10-14  976.3100    0.0000 1,830.4758     0.0000        0       NaN
# 2019-10-15  993.5093    0.0000 1,739.4679     0.0000        0       NaN
#
#             curve  ...  radioshack  apeswap  frax-swap  stargate  ghostmarket  \
# date               ...
# 2019-10-11    NaN  ...         NaN      NaN        NaN       NaN          NaN
# 2019-10-12    NaN  ...         NaN      NaN        NaN       NaN          NaN
# 2019-10-13    NaN  ...         NaN      NaN        NaN       NaN          NaN
# 2019-10-14    NaN  ...         NaN      NaN        NaN       NaN          NaN
# 2019-10-15    NaN  ...         NaN      NaN        NaN       NaN          NaN
#
#             pancakeswap  dodo
# date
# 2019-10-11          NaN   NaN
# 2019-10-12          NaN   NaN
# 2019-10-13          NaN   NaN
# 2019-10-14          NaN   NaN
# 2019-10-15          NaN   NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Get daily fees and revenue of a specific protocol

# %%
df = obj.get_daily_fees_this_protocol(protocol='gmx', data_type='dailyFees')
print(df.head(), end='\n\n')
print(df.tail())
# Out:
#                  fees
# date
# 2021-09-02 3,340.5044
# 2021-09-03 4,537.8886
# 2021-09-04 1,070.6653
# 2021-09-05 1,167.3130
# 2021-09-06 6,340.0759
#
#                    fees
# date
# 2022-12-23 465,253.7229
# 2022-12-24  49,510.0475
# 2022-12-25 106,891.6622
# 2022-12-26  58,115.4434
# 2022-12-27 150,605.2307

# %%
df = obj.get_daily_fees_this_protocol(protocol='gmx', data_type='dailyRevenue')
print(df.head(), end='\n\n')
print(df.tail())
# Out:
#               revenue
# date
# 2021-09-02 1,002.1513
# 2021-09-03 1,361.3666
# 2021-09-04   321.1996
# 2021-09-05   350.1939
# 2021-09-06 1,902.0228
#
#                 revenue
# date
# 2022-12-23 139,576.1169
# 2022-12-24  14,853.0143
# 2022-12-25  32,067.4987
# 2022-12-26  17,434.6330
# 2022-12-27  45,181.5692
