# %%
from defillama2 import DefiLlama
import pandas as pd

pd.set_option('display.max_columns', 15)
pd.set_option('display.max_rows', 50)
pd.options.display.float_format = '{:,.4f}'.format

# %% [markdown]
# ## Create a DefiLlama instance

# %%
obj = DefiLlama()

# %% [markdown]
# ## Get all stablecoins along with their circulating amounts

# %%
obj.get_stablecoins_circulating()
# Out:
#                 name symbol            gecko_id    pegType  priceSource  \
# id
# 1             Tether   USDT              tether  peggedUSD    chainlink
# 2           USD Coin   USDC            usd-coin  peggedUSD    chainlink
# 3    TerraClassicUSD   USTC            terrausd  peggedUSD    chainlink
# 4        Binance USD   BUSD         binance-usd  peggedUSD    chainlink
# 5                Dai    DAI                 dai  peggedUSD    chainlink
# ..               ...    ...                 ...        ...          ...
# 77              LUGH   EURL                lugh  peggedEUR         None
# 78              Note   NOTE                note  peggedUSD    coingecko
# 79  Destablecoin HAY    HAY  helio-protocol-hay  peggedUSD  dexscreener
# 80              USD2   USD2                usd2  peggedUSD       kaddex
# 81               USK    USK                 usk  peggedUSD    coingecko
#
#      pegMechanism         circulating  circulatingPrevDay  \
# id
# 1     fiat-backed 68,057,722,035.6468 68,045,831,589.5906
# 2     fiat-backed 45,975,464,756.2830 46,509,772,649.2641
# 3     algorithmic  9,815,051,452.1074  9,815,244,001.3302
# 4     fiat-backed 21,147,288,499.7700 20,882,575,007.8200
# 5   crypto-backed  6,348,036,688.7830  6,325,915,250.7732
# ..            ...                 ...                 ...
# 77    fiat-backed      5,150,010.0000      5,150,010.0000
# 78  crypto-backed     15,341,374.8647     15,395,386.7318
# 79  crypto-backed     30,453,837.0144     30,309,230.6533
# 80  crypto-backed         62,626.8136         62,626.8136
# 81  crypto-backed        222,744.7893        222,558.2697
#
#     circulatingPrevWeek  circulatingPrevMonth
# id
# 1   67,951,354,336.0667   67,549,551,674.6724
# 2   48,523,570,145.0808   51,194,436,491.4446
# 3    9,816,096,112.7103    9,815,490,842.4023
# 4   21,046,716,898.0100   19,433,224,185.5300
# 5    6,443,021,780.6572    6,452,115,147.7578
# ..                  ...                   ...
# 77       5,140,010.0000        5,240,010.0000
# 78      15,517,803.3428       22,650,050.8404
# 79      29,327,280.0923                0.0000
# 80          62,626.8136                0.0000
# 81         229,356.1577                0.0000
#
# [81 rows x 10 columns]

# %%
dd = obj.get_stablecoins_circulating_by_chain()

# %%
dd['USDT']
# Out:
#                 type            current  circulatingPrevDay  \
# chain
# Optimism   peggedUSD    87,607,986.6312     86,900,719.8499
# Statemine  peggedUSD     3,490,005.0000      3,490,005.0000
# Harmony    peggedUSD             0.0000              0.0000
# BSC        peggedUSD 4,976,290,762.1491  4,976,297,297.6372
# Dogechain  peggedUSD       663,855.4299        654,994.2863
# ...              ...                ...                 ...
# Theta      peggedUSD         1,132.4231          1,132.4231
# NEO        peggedUSD     6,855,446.0000      6,855,446.0000
# Syscoin    peggedUSD        84,782.6868         84,782.6868
# Solana     peggedUSD 1,810,379,883.0945  1,904,323,110.0299
# Everscale  peggedUSD     5,775,945.8952      5,965,616.7847
#
#            circulatingPrevWeek  circulatingPrevMonth
# chain
# Optimism       84,431,655.8861       85,056,451.1787
# Statemine       3,490,005.0000        3,490,005.0000
# Harmony                 0.0000                0.0000
# BSC         4,976,299,906.4022    4,976,287,384.0196
# Dogechain         848,195.8827        2,164,378.8743
# ...                        ...                   ...
# Theta               1,132.4231            1,132.4231
# NEO             6,855,446.0000        6,855,446.0000
# Syscoin            84,782.6868           86,582.3145
# Solana      1,810,483,534.5241    1,810,442,412.0041
# Everscale       5,692,575.8846        6,585,371.2053
#
# [60 rows x 5 columns]

# %%
dd['USDC']
# Out:
#                 type            current  circulatingPrevDay  \
# chain
# Optimism   peggedUSD   446,230,517.3013    446,963,547.3296
# DFK        peggedUSD     3,518,000.5785      3,555,064.6433
# Kadena     peggedUSD             0.0000              0.0000
# BSC        peggedUSD 1,181,731,236.3083  1,181,738,505.9510
# Flow       peggedUSD    14,283,349.0000     14,250,179.0000
# ...              ...                ...                 ...
# Syscoin    peggedUSD       672,122.1997        672,122.1997
# Solana     peggedUSD 2,922,046,889.2886  3,140,450,429.6732
# Ronin      peggedUSD    32,945,939.6023     32,945,939.6023
# Elrond     peggedUSD    42,034,271.8709     41,973,090.1520
# Everscale  peggedUSD     4,226,027.3544      4,274,201.5913
#
#            circulatingPrevWeek  circulatingPrevMonth
# chain
# Optimism      413,907,404.0822      389,273,644.4288
# DFK             3,560,660.3732                0.0000
# Kadena                  0.0000          218,675.4653
# BSC         1,181,745,306.2466    1,181,810,039.6908
# Flow           15,519,508.0000       13,839,498.0000
# ...                        ...                   ...
# Syscoin           671,122.1997          723,647.3691
# Solana      3,183,865,682.8166    3,926,934,768.5565
# Ronin          32,945,939.6023       32,945,939.6023
# Elrond         41,944,112.1574       43,093,711.8583
# Everscale       4,572,750.3495        5,072,671.2014
#
# [58 rows x 5 columns]

# %%
dd['EURL']
# Out:
#                type  current  circulatingPrevDay  circulatingPrevWeek  \
# chain
# Ethereum  peggedEUR     5010                5010                 5010
# Tezos     peggedEUR  5145000             5145000              5135000
#
#           circulatingPrevMonth
# chain
# Ethereum                  5010
# Tezos                  5235000

# %% [markdown]
# ## Get all available historical mcaps of a stablecoin

# %%
# get stablecoin ids
df = obj.get_stablecoins_circulating()
ss = df.loc[:, 'name']
ss
# Out:
# id
# 1               Tether
# 2             USD Coin
# 3      TerraClassicUSD
# 4          Binance USD
# 5                  Dai
#             ...
# 77                LUGH
# 78                Note
# 79    Destablecoin HAY
# 80                USD2
# 81                 USK
# Name: name, Length: 81, dtype: object

# %%
obj.get_stablecoin_hist_mcap(1) # USDT
# Out:
#               totalCirculating    totalUnreleased  totalCirculatingUSD  \
# date
# 2021-01-01 20,934,027,063.0407             0.0000  20,935,116,985.4935
# 2021-01-02 21,123,644,615.3857             0.0000  21,165,735,737.9266
# 2021-01-03 21,202,977,966.9670             0.0000  21,269,142,057.2449
# 2021-01-04 21,350,523,809.2807             0.0000  21,365,921,518.0764
# 2021-01-05 21,808,226,475.3264             0.0000  21,801,817,637.4862
# ...                        ...                ...                  ...
# 2022-10-01 67,944,572,025.1370 2,349,390,354.6413  67,948,542,705.9262
# 2022-10-02 67,944,572,025.1370 2,349,390,354.6413  67,949,182,064.3489
# 2022-10-03 67,944,572,025.1370 2,349,390,354.6413  67,944,572,025.1370
# 2022-10-04 67,944,722,035.7808 2,349,240,343.9872  67,947,697,335.1587
# 2022-10-05 68,057,722,035.6468 2,236,240,343.9872  68,074,624,851.4916
#
#             totalMintedUSD  totalBridgedToUSD
# date
# 2021-01-01               0                  0
# 2021-01-02               0                  0
# 2021-01-03               0                  0
# 2021-01-04               0                  0
# 2021-01-05               0                  0
# ...                    ...                ...
# 2022-10-01               0                  0
# 2022-10-02               0                  0
# 2022-10-03               0                  0
# 2022-10-04               0                  0
# 2022-10-05               0                  0
#
# [643 rows x 5 columns]

# %%
obj.get_stablecoin_hist_mcap(2) # USDC
# Out:
#               totalCirculating    totalUnreleased  totalCirculatingUSD  \
# date
# 2021-01-01  3,925,840,105.2083             0.0000   3,931,691,995.7085
# 2021-01-02  4,123,724,902.2272             0.0000   4,121,592,025.5758
# 2021-01-03  4,128,120,369.1505             0.0000   4,138,858,681.0652
# 2021-01-04  4,227,905,606.0224             0.0000   4,213,378,134.3475
# 2021-01-05  4,254,328,706.9059             0.0000   4,173,046,861.3466
# ...                        ...                ...                  ...
# 2022-10-01 46,619,611,046.8697 2,519,232,947.9286  46,619,333,660.1840
# 2022-10-02 46,613,738,497.3778 2,521,246,288.0492  46,613,738,497.3778
# 2022-10-03 46,678,435,900.3699 2,556,425,875.2870  46,680,314,240.6306
# 2022-10-04 46,509,624,315.7967 2,579,491,690.0776  46,510,634,969.9331
# 2022-10-05 45,975,464,756.2830 2,879,667,006.4180  45,971,625,345.2212
#
#             totalMintedUSD  totalBridgedToUSD
# date
# 2021-01-01               0                  0
# 2021-01-02               0                  0
# 2021-01-03               0                  0
# 2021-01-04               0                  0
# 2021-01-05               0                  0
# ...                    ...                ...
# 2022-10-01               0                  0
# 2022-10-02               0                  0
# 2022-10-03               0                  0
# 2022-10-04               0                  0
# 2022-10-05               0                  0
#
# [643 rows x 5 columns]

# %%
frax_id = ss.index[ss == 'Frax'].values[0]
print('Frax id:', frax_id)
obj.get_stablecoin_hist_mcap(frax_id) # Frax
# Out:
# Frax id: 6
#              totalCirculating  totalUnreleased  totalCirculatingUSD  \
# date
# 2021-01-01    57,389,050.4678                0      57,182,625.2793
# 2021-01-02    71,772,627.9154                0      72,715,225.4559
# 2021-01-03    78,289,715.7593                0      79,285,756.9220
# 2021-01-04    78,876,977.8695                0      79,385,984.5492
# 2021-01-05    76,277,371.0968                0      74,936,731.8739
# ...                       ...              ...                  ...
# 2022-10-01 1,356,065,653.3713                0   1,354,906,217.2377
# 2022-10-02 1,356,065,653.3713                0   1,355,284,966.3747
# 2022-10-03 1,358,065,653.3713                0   1,354,399,935.3984
# 2022-10-04 1,358,065,653.3713                0   1,356,018,708.9153
# 2022-10-05 1,358,065,653.3713                0   1,358,344,735.8631
#
#             totalMintedUSD  totalBridgedToUSD
# date
# 2021-01-01               0                  0
# 2021-01-02               0                  0
# 2021-01-03               0                  0
# 2021-01-04               0                  0
# 2021-01-05               0                  0
# ...                    ...                ...
# 2022-10-01               0                  0
# 2022-10-02               0                  0
# 2022-10-03               0                  0
# 2022-10-04               0                  0
# 2022-10-05               0                  0
#
# [643 rows x 5 columns]

# %% [markdown]
# ## Get all available historical mcaps of a stablecoin on a particular chain

# %%
obj.get_stablecoin_hist_mcap_on_a_chain(1, 'ethereum') # USDT on ethereum
# Out:
#               totalCirculating    totalUnreleased  totalCirculatingUSD  \
# date
# 2021-01-01 13,127,933,832.9708   159,742,117.5663  13,128,617,334.0382
# 2021-01-02 13,118,372,135.7156   164,742,117.5763  13,144,511,896.1194
# 2021-01-03 13,126,053,611.9272   146,742,117.5763  13,167,013,584.5087
# 2021-01-04 13,266,134,880.8645    35,742,117.5763  13,275,702,237.7858
# 2021-01-05 13,255,191,132.4793    12,442,117.5763  13,251,295,796.4415
# ...                        ...                ...                  ...
# 2022-10-01 28,295,582,168.1439 1,094,749,656.9541  28,297,235,761.9658
# 2022-10-02 28,290,420,865.9381 1,094,749,656.9541  28,292,340,370.9939
# 2022-10-03 28,288,470,101.8997 1,094,749,656.9541  28,288,470,101.8997
# 2022-10-04 28,217,885,903.2993 1,169,749,656.9541  28,219,121,564.5230
# 2022-10-05 28,219,139,802.1847 1,169,749,656.9541  28,226,148,307.7460
#
#                 totalMintedUSD  totalBridgedToUSD
# date
# 2021-01-01 13,382,968,146.8907             0.0000
# 2021-01-02 13,403,927,048.7236             0.0000
# 2021-01-03 13,437,071,473.0300             0.0000
# 2021-01-04 13,516,011,943.9522             0.0000
# 2021-01-05 13,525,595,434.9692             0.0000
# ...                        ...                ...
# 2022-10-01 31,217,456,370.5060        37,580.1519
# 2022-10-02 31,217,750,109.6043        37,580.5055
# 2022-10-03 31,215,632,128.9644        37,594.0011
# 2022-10-04 31,141,995,777.2453        37,645.6495
# 2022-10-05 31,148,366,216.3599        37,653.3504
#
# [643 rows x 5 columns]

# %%
obj.get_stablecoin_hist_mcap_on_a_chain(2, 'arbitrum') # USDC on arbitrum
# Out:
#             totalCirculating  totalUnreleased  totalCirculatingUSD  \
# date
# 2021-01-01            0.0000                0               0.0000
# 2021-01-02            0.0000                0               0.0000
# 2021-01-03            0.0000                0               0.0000
# 2021-01-04            0.0000                0               0.0000
# 2021-01-05            0.0000                0               0.0000
# ...                      ...              ...                  ...
# 2022-10-01  898,098,093.2875                0     898,092,749.6039
# 2022-10-02  898,720,881.5404                0     898,720,881.5404
# 2022-10-03  899,654,202.0518                0     899,690,404.1368
# 2022-10-04  900,459,899.4375                0     900,479,466.4311
# 2022-10-05  900,742,649.8681                0     900,667,428.8494
#
#             totalMintedUSD  totalBridgedToUSD
# date
# 2021-01-01               0             0.0000
# 2021-01-02               0             0.0000
# 2021-01-03               0             0.0000
# 2021-01-04               0             0.0000
# 2021-01-05               0             0.0000
# ...                    ...                ...
# 2022-10-01               0   898,092,749.6039
# 2022-10-02               0   898,720,881.5404
# 2022-10-03               0   899,690,404.1368
# 2022-10-04               0   900,479,466.4311
# 2022-10-05               0   900,667,428.8494
#
# [643 rows x 5 columns]

# %% [markdown]
# ## Get current total mcap of all stablecoins on each chain.

# %%
obj.get_stablecoins_curr_mcap_by_chain()
# Out:
#                type  totalCirculatingUSD
# chain
# Optimism  peggedEUR         815,838.8240
# Optimism  peggedUSD     773,983,524.8344
# Optimism  peggedVAR          52,801.6064
# DFK       peggedUSD       3,517,729.2921
# Kadena    peggedUSD          62,626.8136
# ...             ...                  ...
# Cronos    peggedUSD         439,247.0475
# Mixin     peggedUSD      23,071,793.7455
# Kujira    peggedUSD         225,640.4715
# Acala     peggedUSD               0.0000
# smartBCH  peggedUSD      41,214,024.1892
#
# [103 rows x 2 columns]

# %% [markdown]
# ## Get historical prices of all stablecoins

# %%
obj.get_stablecoins_prices()
# Out:
#                  stablecoin  prices
# date
# 2020-12-30      binance-usd  1.0035
# 2020-12-30      celo-dollar  1.0035
# 2020-12-30              dai  1.0043
# 2020-12-30             frax  1.0275
# 2020-12-30    gemini-dollar  1.0078
# ...                     ...     ...
# 2022-10-05     vesta-stable  0.9812
# 2022-10-05    volt-protocol  1.0290
# 2022-10-05      youves-uusd  0.9944
# 2022-10-05  yusd-stablecoin  0.9942
# 2022-10-05             zusd     NaN
#
# [24230 rows x 2 columns]
