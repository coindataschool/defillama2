# %%
from defillama2 import DefiLlama
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 15)
pd.set_option('display.max_rows', 50)
pd.options.display.float_format = '{:,.4f}'.format

# %%
obj = DefiLlama()

# %% [markdown]
# ## Get Dexes Volumes

# %%
dd = obj.get_dexes_volumes()
dd.keys()
# Out:
# dict_keys(['volume_overall', 'volume_by_dex', 'volume_by_dex_by_chain_24h', 'daily_volume', 'daily_volume_by_dex'])

# %%
dd['volume_overall']
# Out:
#             total24h            total7d  change_1d  change_7d  change_1m  \
# 0 1,096,411,616.0676 7,350,773,909.2084    15.4700   -31.5200   -25.5700
#
#    change_7dover7d
# 0         -37.8800

# %%
dd['volume_by_dex'].head()
# Out:
#         name category  change_1d  change_7d  change_1m  change_7dover7d  \
# 0         0x    Dexes     9.8200     2.7400   -83.9700         -14.8400
# 1    10KSwap    Dexes    -1.2200     4.5700   -57.7600          14.5500
# 2  3xcalibur    Dexes   -11.8300    -6.2600   -53.4400         -38.8400
# 3      4Swap    Dexes   441.0800    30.4900   -86.8700         -70.3600
# 4     Aldrin    Dexes    55.9700    19.6300    20.8600         -51.7500
#
#         total24h         total7d       totalAllTime               chains
# 0 8,033,287.6937 43,593,960.6757                NaN  [Ethereum, Polygon]
# 1   111,885.8440    804,920.5706     8,747,834.2401           [Starknet]
# 2    60,067.8023    371,605.2606    28,180,642.6546           [Arbitrum]
# 3 2,502,968.5200  8,578,025.8300                NaN              [Mixin]
# 4    33,618.6248    197,373.1812 1,064,231,733.2966             [Solana]

# %%
dd['volume_by_dex_by_chain_24h'].head()
# Out:
#     protocol     chain       total24h
# 0     0x RFQ  ethereum 8,028,277.4797
# 1     0x RFQ   polygon     5,010.2139
# 2    10kswap  starknet   111,885.8440
# 3  3xcalibur  arbitrum    60,067.8023
# 4      4swap     mixin 2,502,968.5200

# %%
dd['daily_volume'].head()
# Out:
#                  volume
# date
# 2019-10-11 929,560.1687
# 2019-10-12 369,449.1841
# 2019-10-13 425,513.3585
# 2019-10-14 786,171.7473
# 2019-10-15 664,778.7958

# %%
dd['daily_volume_by_dex'].tail()
# Out:
#                     uniswap             dodo         sunswap   honeyswap  \
# date
# 2022-12-23 559,475,398.4701 110,425,730.4900  7,175,985.9387 15,313.9068
# 2022-12-24 202,265,420.3883  44,261,748.0900  9,541,328.1460  7,922.2355
# 2022-12-25 432,093,128.4850  49,529,426.4100  7,006,410.7169  6,716.7764
# 2022-12-26 362,718,950.6969  74,222,031.3000  2,728,857.2024 10,997.5633
# 2022-12-27 563,997,361.9874           0.0000 10,471,860.1419 16,857.7301
#
#                  sushiswap     pancakeswap         dfyn  ...       openbook  \
# date                                                     ...
# 2022-12-23 13,456,803.8714 91,370,263.4126  39,754.1943  ...   724,917.0894
# 2022-12-24 10,049,311.4294 81,106,353.3077  71,738.5667  ... 1,100,196.5759
# 2022-12-25 14,655,646.0073 88,217,795.9991  86,978.3935  ...   658,863.7600
# 2022-12-26 47,176,526.3635 87,327,686.4261 101,967.5740  ...   832,830.4493
# 2022-12-27 50,372,505.4967 88,665,880.8574 118,327.3786  ... 1,899,348.9558
#
#                  myswap   liquidswap   koyo  smbswap   wx.network  \
# date
# 2022-12-23  90,714.6673 133,383.0914 0.0000  96.9931 761,975.7218
# 2022-12-24  81,351.3907 112,372.7555 0.0000  59.5564 490,516.2649
# 2022-12-25 118,405.8193 110,485.3047 0.0000  21.6705 550,775.8427
# 2022-12-26  81,220.2001 120,797.4478 0.0000   6.8845 997,604.1217
# 2022-12-27  81,220.2001 126,898.2496 0.0000  50.7408 550,093.6666
#
#             aux-exchange
# date
# 2022-12-23  528,017.4236
# 2022-12-24  307,207.6149
# 2022-12-25  513,985.4619
# 2022-12-26  377,789.4366
# 2022-12-27  341,767.2488
#
# [5 rows x 209 columns]

# %% [markdown]
# ## Get dexes volumes from a particular chain

# %%
dd = obj.get_dexes_volumes_this_chain('ethereum')
dd.keys()
# Out:
# dict_keys(['volume_overall', 'volume_by_dex', 'volume_by_dex_by_chain_24h', 'daily_volume', 'daily_volume_by_dex'])

# %%
dd['volume_overall']
# Out:
#           total24h            total7d  change_1d  change_7d  change_1m  \
# 0 764,775,026.9676 4,870,149,877.6921         15   -29.1500   -24.0400
#
#    change_7dover7d
# 0         -36.9100

# %%
dd['volume_by_dex'].head()
# Out:
#           name category  change_1d  change_7d  change_1m  change_7dover7d  \
# 0           0x    Dexes     9.7800     2.7100   -83.9800         -14.8600
# 1  ApeSwap AMM    Dexes 1,291.6000   -80.5000   -81.6800         -53.3200
# 2     Balancer    Dexes    -7.6700   -60.9900   -19.5100         -26.0600
# 3  Bancor V2.1    Dexes   -42.3800    47.0200   -80.9500         -55.4000
# 4          BXH    Dexes   -56.9200   -77.0200   -93.4800         -92.6300
#
#          total24h          total7d    totalAllTime      chains
# 0  8,028,277.4797  43,583,493.8411             NaN  [Ethereum]
# 1        140.5607       3,296.0857    645,073.3132  [Ethereum]
# 2 32,641,424.1191 298,489,105.0138             NaN  [Ethereum]
# 3    142,339.2320     973,726.1145             NaN  [Ethereum]
# 4         10.7600         310.4554 13,606,808.4974  [Ethereum]

# %%
print(dd['volume_by_dex_by_chain_24h'].head(), end='\n\n')
print(dd['volume_by_dex_by_chain_24h']['chain'].unique())
# Out:
#   protocol     chain        total24h
# 0   0x RFQ  ethereum  8,028,277.4797
# 1  apeswap  ethereum        140.5607
# 2       v1  ethereum  1,774,202.1898
# 3       v2  ethereum 30,867,221.9293
# 4     v2.1  ethereum      3,671.6193
#
# ['ethereum']

# %%
dd['daily_volume'].head()
# Out:
#                  volume
# date
# 2019-10-11 929,560.1687
# 2019-10-12 369,449.1841
# 2019-10-13 425,513.3585
# 2019-10-14 786,171.7473
# 2019-10-15 664,778.7958

# %%
dd['daily_volume_by_dex'].tail()
# Out:
#                     uniswap            dodo       sushiswap    luaswap  \
# date
# 2022-12-23 487,800,708.3989 94,794,816.2600  8,393,368.5970 1,176.5391
# 2022-12-24 176,429,106.6899 33,370,942.7800  6,238,174.5707 2,398.4171
# 2022-12-25 374,935,855.9573 38,165,855.9500  8,427,003.4224   429.3208
# 2022-12-26 320,416,785.9300 60,308,478.3200 42,298,518.7067   961.9851
# 2022-12-27 499,483,782.0332          0.0000 45,148,627.5527   937.8392
#
#                 swapr             0x   mooniswap  ...  wardenswap  \
# date                                              ...
# 2022-12-23 7,218.2460 6,364,836.2237 24,273.0310  ...     70.4308
# 2022-12-24 3,042.8861 5,131,784.0187 33,312.7780  ...     57.0260
# 2022-12-25 7,117.5168 3,652,330.8056 21,668.9753  ...     43.6212
# 2022-12-26 6,472.5075 7,313,107.3627 46,907.2014  ...    318.6887
# 2022-12-27 7,468.6011 8,028,277.4797 36,799.4402  ...    593.7561
#
#                  hashflow            curve  pancakeswap   defiplaza     bxh  \
# date
# 2022-12-23 4,678,371.0300 161,546,777.4463  58,924.7057 10,210.3999 24.9787
# 2022-12-24 3,603,511.2500  70,928,493.6428  69,490.7103  7,498.9495 10.7600
# 2022-12-25 2,374,685.6200 184,728,168.5437 110,336.8326  5,317.2748 10.7600
# 2022-12-26 3,378,928.2600 179,555,052.4827  60,245.0530  8,614.1868 10.7600
# 2022-12-27 3,378,928.2600 158,182,383.4094 148,826.1473  4,038.1875 10.7600
#
#                  bancor
# date
# 2022-12-23 231,722.5661
# 2022-12-24  38,665.1719
# 2022-12-25  57,473.9905
# 2022-12-26 247,046.1800
# 2022-12-27 142,339.2320
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Get volumes of a specific dex

# %%
df = obj.get_daily_volumes_this_dex('uniswap')
df.head()
# Out:
#                volume
# date
# 2018-11-02 1,688.2794
# 2018-11-03 2,537.3706
# 2018-11-04    84.9596
# 2018-11-05   204.3154
# 2018-11-06   793.0623

# %%
df.tail()
# Out:
#                      volume
# date
# 2022-12-23 559,475,398.4701
# 2022-12-24 202,265,420.3883
# 2022-12-25 432,093,128.4850
# 2022-12-26 362,718,950.6969
# 2022-12-27 563,997,361.9874

# %% [markdown]
# ## Get options dexes volumes

# %%
dd = obj.get_options_dexes_volumes(data_type='dailyNotionalVolume')
dd.keys()
# Out:
# dict_keys(['volume_overall', 'volume_by_dex', 'volume_by_dex_by_chain_24h', 'daily_volume', 'daily_volume_by_dex'])

# %%
dd['volume_overall']
# Out:
#         total24h         total7d  change_1d  change_7d  change_1m  \
# 0 2,165,331.3242 18,381,574.3263    -1.8900    -8.9400   -17.6200
#
#    change_7dover7d
# 0         -22.7800

# %%
dd['volume_by_dex'].head()
# Out:
#      name category  change_1d  change_7d  change_1m  change_7dover7d  \
# 0    Lyra  Options    -2.5500    -1.0300     5.7700         -23.0000
# 1  Premia  Options     5.1400   -49.0100   -74.0400         -20.9500
#
#         total24h         total7d     totalAllTime  \
# 0 1,965,287.0000 16,413,017.0000 354,331,550.0000
# 1   200,044.3242  1,968,557.3263 238,345,997.9332
#
#                                    chains  dailyPremiumVolume
# 0                              [Optimism]         82,534.0000
# 1  [Ethereum, Arbitrum, Fantom, Optimism]            231.7416

# %%
dd['volume_by_dex_by_chain_24h'].head()
# Out:
#   protocol     chain       total24h
# 0     lyra  optimism 1,965,287.0000
# 1   premia  optimism    53,730.8056
# 2   premia  ethereum     8,595.0304
# 3   premia  arbitrum   107,327.9244
# 4   premia    fantom    30,390.5638

# %%
dd['daily_volume'].head()
# Out:
#                    volume
# date
# 2022-06-26   835,736.3923
# 2022-06-27   834,122.4976
# 2022-06-28 1,320,378.7838
# 2022-06-29   630,058.1138
# 2022-06-30 1,307,614.0193

# %%
dd['daily_volume_by_dex'].head()
# Out:
#                    premia         lyra
# date
# 2022-06-26   835,736.3923          NaN
# 2022-06-27   834,122.4976          NaN
# 2022-06-28 1,320,378.7838          NaN
# 2022-06-29   630,058.1138          NaN
# 2022-06-30   667,337.0193 640,277.0000

# %% [markdown]
# ## Get options dexes volumes from a particular chain

# %%
dd = obj.get_options_dexes_volumes_this_chain(chain='arbitrum', 
                                              data_type='dailyPremiumVolume')
dd.keys()
# Out:
# dict_keys(['volume_overall', 'volume_by_dex', 'volume_by_dex_by_chain_24h', 'daily_volume', 'daily_volume_by_dex'])

# %%
dd['volume_overall']
# Out:
#    total24h  total7d  change_1d  change_7d  change_1m  change_7dover7d
# 0   59.8864 676.7580    13.0600        -70   -88.7700         -21.6100

# %%
dd['volume_by_dex']
# Out:
#      name category  change_1d  change_7d  change_1m  change_7dover7d  \
# 0  Premia  Options    13.0600        -70   -88.7700         -21.6100
#
#    total24h  total7d  totalAllTime      chains  dailyPremiumVolume
# 0   59.8864 676.7580  106,422.6923  [Arbitrum]             59.8864

# %%
dd['volume_by_dex_by_chain_24h']
# Out:
#   protocol     chain  total24h
# 0   premia  arbitrum   59.8864

# %%
dd['daily_volume'].head()
# Out:
#              volume
# date
# 2022-06-26 849.6603
# 2022-06-27 367.9586
# 2022-06-28 322.1769
# 2022-06-29  81.6851
# 2022-06-30  81.6851

# %%
dd['daily_volume_by_dex'].head()
# Out:
#              premia
# date
# 2022-06-26 849.6603
# 2022-06-27 367.9586
# 2022-06-28 322.1769
# 2022-06-29  81.6851
# 2022-06-30  81.6851

# %% [markdown]
# ## Get volumes of a specific options dex

# %%
df1 = obj.get_daily_volumes_this_options_dex('lyra')
df2 = obj.get_daily_volumes_this_options_dex('lyra', data_type='dailyPremiumVolume')
print(df1.head())
print(df2.head())
# Out:
#             volume
# date
# 2022-06-30  640277
# 2022-07-01  801721
# 2022-07-02  868407
# 2022-07-03  221466
# 2022-07-04  284933
#             volume
# date
# 2022-06-30   28482
# 2022-07-01   48212
# 2022-07-02   43164
# 2022-07-03   10126
# 2022-07-04   12263

# %%
print(df1.tail())
print(df2.tail())
# Out:
#              volume
# date
# 2022-12-23  3056984
# 2022-12-24  2744592
# 2022-12-25  1810184
# 2022-12-26  2016671
# 2022-12-27  1965287
#             volume
# date
# 2022-12-23   84583
# 2022-12-24  101487
# 2022-12-25   81406
# 2022-12-26   85467
# 2022-12-27   82534
